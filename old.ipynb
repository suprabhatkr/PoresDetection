# %%
cd /content/drive/MyDrive/minor
# Out:
# /content/drive/MyDrive/minor

# %%
# !python3 pores.py
# Out:
# pores_match= 0.9969235707240759

# %%
# !python3 generate_imagetext.py

# %%
# !gcc matching.c

# %%
# !./a.out
# Out:
# 1 = 1(1.000000)
# 2 = 2(0.669415)
# 3 = 3(0.569644)
# 4 = 4(0.610768)
# 5 = 5(0.690340)
# 6 = 6(0.606746)
# 7 = 7(0.641928)
# 8 = 8(0.562029)
# 9 = 9(0.614747)
# 10 = 10(0.592597)
# 11 = 11(0.584179)
# 12 = 12(0.763625)
# 13 = 13(0.627260)
# 14 = 14(0.641685)
# 15 = 15(0.592909)
# 16 = 16(1.000000)
# 17 = 17(0.600838)
# 18 = 18(0.626329)
# 19 = 19(0.578414)
# 20 = 20(0.761865)
# 21 = 21(0.713506)
# 22 = 22(0.715820)
# 23 = 23(0.708447)
# 24 = 24(0.784051)
# 25 = 25(0.630007)
# 26 = 26(0.593665)
# 27 = 27(0.636171)
# 28 = 28(0.669437)
# 29 = 29(0.766341)
# 30 = 30(0.601460)
# 0.671807
